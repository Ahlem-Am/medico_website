# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('cancer.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'diagnosis', data = data)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
dataset = data
dataset['diagnosis'].replace(['M','B'], ['Malade','Sain'], inplace = True)

# %%
dataset.drop('Unnamed: 32',axis = 1, inplace = True)

# %%
dataset.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
corr = dataset.corr()
plt.figure(figsize = (20,25))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
dataset.drop(['id','symmetry_se','smoothness_se','texture_se','fractal_dimension_mean'], axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    Malade        17.99         10.38          122.80     1001.0
# 1    Malade        20.57         17.77          132.90     1326.0
# 2    Malade        19.69         21.25          130.00     1203.0
# 3    Malade        11.42         20.38           77.58      386.1
# 4    Malade        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
plt.figure(figsize = (25,25))
sns.heatmap(dataset.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
# table fait
X = dataset.drop('diagnosis', axis = 1)
Fdiagnosis= dataset['diagnosis']

# %%
X.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# Dimension Forme:
# ** perimeter,radius,area,concavity,symmetry,fractal_dimension:
# perimeter_mean/perimeter_se/perimeter_worst
# radius_mean/radius_worst/radius_se
# area_mean/area_worst/area_se
# concavity_mean/fractal_dimension_se/concave points_mean/concave points_se/concave points_worst/concavity_worst
# symmetry_mean/symmetry_worst
# fractal_dimension_se/fractal_dimension_worst/

# %%
DForme=X[['perimeter_mean','perimeter_se','perimeter_worst',
'radius_mean','radius_worst','radius_se',
'area_mean','area_worst','area_se',
'concavity_mean','concavity_se','concave points_mean','concave points_se','concave points_worst','concavity_worst',
'symmetry_mean','symmetry_worst',
'fractal_dimension_se','fractal_dimension_worst']]


X.drop(['perimeter_mean','perimeter_se','perimeter_worst',
'radius_mean','radius_worst','radius_se',
'area_mean','area_worst','area_se',
'concavity_mean','concavity_se','concave points_mean','concave points_se','concave points_worst','concavity_worst',
'symmetry_mean','symmetry_worst',
'fractal_dimension_se','fractal_dimension_worst'], axis = 1, inplace = True)

# %%
X.describe()
# Out:
#        texture_mean  smoothness_mean  compactness_mean  compactness_se  \
# count    569.000000       569.000000        569.000000      569.000000
# mean      19.289649         0.096360          0.104341        0.025478
# std        4.301036         0.014064          0.052813        0.017908
# min        9.710000         0.052630          0.019380        0.002252
# 25%       16.170000         0.086370          0.064920        0.013080
# 50%       18.840000         0.095870          0.092630        0.020450
# 75%       21.800000         0.105300          0.130400        0.032450
# max       39.280000         0.163400          0.345400        0.135400
#
#        texture_worst  smoothness_worst  compactness_worst
# count     569.000000        569.000000         569.000000
# mean       25.677223          0.132369           0.254265
# std         6.146258          0.022832           0.157336
# min        12.020000          0.071170           0.027290
# ...

# %% [markdown]
# Dimension Texture:
# ** texture,smoothness,compactness
# texture_mean,smoothness_mean,compactness_mean
# compactness_se
# texture_worst,smoothness_worst,compactness_worst

# %%
DTexture=X
